# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = '/content/drive/My Drive/Georgia Distance Matrix/BG_pop_centers_Georgia.csv'
BG_pop_centers = pd.read_csv(file_path)
BG_pop_centers.count()
# Out:
# Geography     5533
# STATEFP       5533
# COUNTYFP      5533
# TRACTCE       5533
# BLKGRPCE      5533
# POPULATION    5533
# LATITUDE      5533
# LONGITUDE     5533
# dtype: int64

# %%
file_path = '/content/drive/My Drive/Georgia Distance Matrix/Georgia_Hospital.csv'
Hospital_cd=pd.read_csv(file_path)
Hospital_cd.head()
Hospital_cd.rename(columns={'Latitude_hosp': 'Latitude', 'Longitude_hosp': 'Longitude'}, inplace=True)
Hospital_cd.head()
# Out:
#                              Hospital Perinatal Level    County   Region  \
# 0      Athens Regional Medical Center               2    Clarke  Augusta
# 1                   Doctor's Hospital               2  Richmond  Augusta
# 2  Augusta University Medical Center*               3  Richmond  Augusta
# 3     Saint Mary's Hospital of Athens               2    Clarke  Augusta
# 4                    Trinity Hospital               2  Richmond  Augusta
#
#                                   Address  \
# 0    1199 Prince Avenue, Athens, GA 30606
# 1      3651 Wheeler Rd, Augusta, GA 30909
# 2         1120 15th St, Augusta, GA 30912
# 3        1230 Baxter St, Athens, GA 30606
# 4  2260 Wrightsboro Rd, Augusta, GA 30904
#
#                                 Coordinates   Latitude  Longitude
# 0         (33.96067055, -83.39945647757811)  33.960671 -83.399456
# 1          (33.4864304, -82.09452364191654)  33.486430 -82.094524
# 2  (33.471100050000004, -81.98981674626567)  33.471100 -81.989817
# 3  (33.947457150000005, -83.40529603690919)  33.947457 -83.405296
# 4          (33.4663468, -82.01761137895278)  33.466347 -82.017611

# %%
Hospital_cd = Hospital_cd.drop(columns=['Coordinates'])
Hospital_cd.head()
# Out:
#                              Hospital Perinatal Level    County   Region  \
# 0      Athens Regional Medical Center               2    Clarke  Augusta
# 1                   Doctor's Hospital               2  Richmond  Augusta
# 2  Augusta University Medical Center*               3  Richmond  Augusta
# 3     Saint Mary's Hospital of Athens               2    Clarke  Augusta
# 4                    Trinity Hospital               2  Richmond  Augusta
#
#                                   Address   Latitude  Longitude
# 0    1199 Prince Avenue, Athens, GA 30606  33.960671 -83.399456
# 1      3651 Wheeler Rd, Augusta, GA 30909  33.486430 -82.094524
# 2         1120 15th St, Augusta, GA 30912  33.471100 -81.989817
# 3        1230 Baxter St, Athens, GA 30606  33.947457 -83.405296
# 4  2260 Wrightsboro Rd, Augusta, GA 30904  33.466347 -82.017611

# %%
import requests

def get_osrm_road_distance(start_coords, end_coords):
    # Prepare the URL for the OSRM API
    osrm_url = f"http://router.project-osrm.org/route/v1/driving/{start_coords[1]},{start_coords[0]};{end_coords[1]},{end_coords[0]}?overview=false"

    # Send a request to the OSRM API
    response = requests.get(osrm_url)
    data = response.json()

    # Extract the distance from the JSON response
    # Note: OSRM returns distance in meters, so we convert it to miles
    distance_meters = data['routes'][0]['distance']
    distance_miles = distance_meters / 1609.34  # Convert meters to miles

    return distance_miles

# Assuming BG_pop_centers and Hospital_cd are your dataframes with latitude and longitude information
alpha = {}
for b in BG_pop_centers.index[2001:2301]:
    alpha[b] = {}
    print(b)
    for h in Hospital_cd.index:
        b_coords = (BG_pop_centers.loc[b]['LATITUDE'], BG_pop_centers.loc[b]['LONGITUDE'])
        h_coords = (Hospital_cd.loc[h]['Latitude'], Hospital_cd.loc[h]['Longitude'])

        # Use the OSRM API to get road distance in miles
        dist = get_osrm_road_distance(b_coords, h_coords)

        alpha[b][h] = dist
# Out:
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2023
# 2024
# 2025
# 2026
# 2027
# 2028
# 2029
# 2030
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2037
# 2038
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2047
# 2048
# 2049
# 2050
# 2051
# 2052
# 2053
# 2054
# 2055
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063
# 2064
# 2065
# 2066
# 2067
# 2068
# 2069
# 2070
# 2071
# 2072
# 2073
# 2074
# 2075
# 2076
# 2077
# 2078
# 2079
# 2080
# 2081
# 2082
# 2083
# 2084
# 2085
# 2086
# 2087
# 2088
# 2089
# 2090
# 2091
# 2092
# 2093
# 2094
# 2095
# 2096
# 2097
# 2098
# 2099
# 2100
# 2101
# 2102
# 2103
# 2104
# 2105
# 2106
# 2107
# 2108
# 2109
# 2110
# 2111
# 2112
# 2113
# 2114
# 2115
# 2116
# 2117
# 2118
# 2119
# 2120
# 2121
# 2122
# 2123
# 2124
# 2125
# 2126
# 2127
# 2128
# 2129
# 2130
# 2131
# 2132
# 2133
# 2134
# 2135
# 2136
# 2137
# 2138
# 2139
# 2140
# 2141
# 2142
# 2143
# 2144
# 2145
# 2146
# 2147
# 2148
# 2149
# 2150
# 2151
# 2152
# 2153
# 2154
# 2155
# 2156
# 2157
# 2158
# 2159
# 2160
# 2161
# 2162
# 2163
# 2164
# 2165
# 2166
# 2167
# 2168
# 2169
# 2170
# 2171
# 2172
# 2173
# 2174
# 2175
# 2176
# 2177
# 2178
# 2179
# 2180
# 2181
# 2182
# 2183
# 2184
# 2185
# 2186
# 2187
# 2188
# 2189
# 2190
# 2191
# 2192
# 2193
# 2194
# 2195
# 2196
# 2197
# 2198
# 2199
# 2200
# 2201
# 2202
# 2203
# 2204
# 2205
# 2206
# 2207
# 2208
# 2209
# 2210
# 2211
# 2212
# 2213
# 2214
# 2215
# 2216
# 2217
# 2218
# 2219
# 2220
# 2221
# 2222
# 2223
# 2224
# 2225
# 2226
# 2227
# 2228
# 2229
# 2230
# 2231
# 2232
# 2233
# 2234
# 2235
# 2236
# 2237
# 2238
# 2239
# 2240
# 2241
# 2242
# 2243
# 2244
# 2245
# 2246
# 2247
# 2248
# 2249
# 2250
# 2251
# 2252
# 2253
# 2254
# 2255
# 2256
# 2257
# 2258
# 2259
# 2260
# 2261
# 2262
# 2263
# 2264
# 2265
# 2266
# 2267
# 2268
# 2269
# 2270
# 2271
# 2272
# 2273
# 2274
# 2275
# 2276
# 2277
# 2278
# 2279
# 2280
# 2281
# 2282
# 2283
# 2284
# 2285
# 2286
# 2287
# 2288
# 2289
# 2290
# 2291
# 2292
# 2293
# 2294
# 2295
# 2296
# 2297
# 2298
# 2299
# 2300

# %%
import numpy as np
import pickle

# Assuming 'alpha' is your original dictionary
alpha = {k: alpha[k] for k in range(2001,2301) if k in alpha}

# Save the filtered dictionary to a file using NumPy
np.save('alpha', alpha)
# save dictionary
with open('/content/drive/My Drive/Georgia Distance Matrix/Distance_Matrix(2001,2300).pkl', 'wb') as fp:
    pickle.dump(alpha, fp)

# %%
with open('/content/drive/My Drive/Georgia Distance Matrix/Distance_Matrix(5513,5532).pkl', 'rb') as file:
    df = pickle.load(file)

# %%
print(df.keys())
# Out:
# dict_keys([5513, 5514, 5515, 5516, 5517, 5518, 5519, 5520, 5521, 5522, 5523, 5524, 5525, 5526, 5527, 5528, 5529, 5530, 5531, 5532])
