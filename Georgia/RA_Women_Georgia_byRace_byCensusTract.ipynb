# %%
import pandas as pd
RA_White=pd.read_csv('../../Obstetric accessibility visualization/Georgia/WhiteRace.csv')

# %%
RA_White.head()
columns_list = RA_White.columns.tolist()

print(columns_list)
# Out:
# ['GEO_ID', 'NAME', 'B01001A_001E', 'B01001A_001EA', 'B01001A_001M', 'B01001A_001MA', 'B01001A_002E', 'B01001A_002EA', 'B01001A_002M', 'B01001A_002MA', 'B01001A_003E', 'B01001A_003M', 'B01001A_003MA', 'B01001A_003EA', 'B01001A_004E', 'B01001A_004M', 'B01001A_004MA', 'B01001A_004EA', 'B01001A_005E', 'B01001A_005M', 'B01001A_005MA', 'B01001A_005EA', 'B01001A_006E', 'B01001A_006EA', 'B01001A_006M', 'B01001A_006MA', 'B01001A_007E', 'B01001A_007EA', 'B01001A_007M', 'B01001A_007MA', 'B01001A_008E', 'B01001A_008EA', 'B01001A_008M', 'B01001A_008MA', 'B01001A_009E', 'B01001A_009EA', 'B01001A_009M', 'B01001A_009MA', 'B01001A_010E', 'B01001A_010EA', 'B01001A_010M', 'B01001A_010MA', 'B01001A_011E', 'B01001A_011M', 'B01001A_011MA', 'B01001A_011EA', 'B01001A_012E', 'B01001A_012EA', 'B01001A_012M', 'B01001A_012MA', 'B01001A_013E', 'B01001A_013EA', 'B01001A_013M', 'B01001A_013MA', 'B01001A_014E', 'B01001A_014EA', 'B01001A_014M', 'B01001A_014MA', 'B01001A_015E', 'B01001A_015EA', 'B01001A_015M', 'B0100
# ...

# %%
RA_White.rename(columns=RA_White.iloc[0], inplace=True)
RA_White_df = RA_White[[
    'Geographic Area Name',
    'Estimate!!Total!!Female!!18 and 19 years',
    'Estimate!!Total!!Female!!20 to 24 years',
    'Estimate!!Total!!Female!!25 to 29 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!35 to 44 years',
]]
RA_White_df_copy = RA_White_df.copy()
RA_White_df_copy.drop(RA_White_df.index[0], inplace=True)
RA_White_df_copy = RA_White_df_copy.set_index('Geographic Area Name')
RA_White_df_copy = RA_White_df_copy.iloc[1:]
RA_White_df_copy = RA_White_df_copy.astype(int)
RA_White_df_copy['Total Female, 18-44'] = RA_White_df_copy.iloc[:, 1:8].sum(axis=1)
RA_White_df_copy = RA_White_df_copy.iloc[:, -1:]
RA_White_df_copy = RA_White_df_copy.rename(columns={'Total Female, 18-44': 'Total White Female, 18-44'})
RA_White_df_copy
# Out:
#                                              Total White Female, 18-44
# Geographic Area Name
# Census Tract 9502, Appling County, Georgia                         360
# Census Tract 9503, Appling County, Georgia                         608
# Census Tract 9504, Appling County, Georgia                         169
# Census Tract 9505, Appling County, Georgia                         541
# Census Tract 9601, Atkinson County, Georgia                        146
# ...                                                                ...
# Census Tract 9501, Worth County, Georgia                           290
# Census Tract 9502, Worth County, Georgia                           824
# Census Tract 9504, Worth County, Georgia                           399
# Census Tract 9505, Worth County, Georgia                           257
# Census Tract 9506, Worth County, Georgia                           213
#
# [1968 rows x 1 columns]

# %%
RA_HispanicORlatino=pd.read_csv('../../Obstetric accessibility visualization/Georgia/HispanicorLatino.csv')

# %%
RA_HispanicORlatino.rename(columns=RA_HispanicORlatino.iloc[0], inplace=True)
RA_HispanicORlatino_df = RA_HispanicORlatino[[
    'Geographic Area Name',
    'Estimate!!Total!!Female!!18 and 19 years',
    'Estimate!!Total!!Female!!20 to 24 years',
    'Estimate!!Total!!Female!!25 to 29 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!35 to 44 years',
]]
RA_HispanicORlatino_df_copy = RA_HispanicORlatino_df.copy()
RA_HispanicORlatino_df_copy.drop(RA_HispanicORlatino_df.index[0], inplace=True)
RA_HispanicORlatino_df_copy = RA_HispanicORlatino_df_copy.set_index('Geographic Area Name')
RA_HispanicORlatino_df_copy = RA_HispanicORlatino_df_copy.iloc[1:]
RA_HispanicORlatino_df_copy = RA_HispanicORlatino_df_copy.astype(int)
RA_HispanicORlatino_df_copy['Total Female, 18-44'] = RA_HispanicORlatino_df_copy.sum(axis=1)
RA_HispanicORlatino_df_copy = RA_HispanicORlatino_df_copy[['Total Female, 18-44']]
RA_HispanicORlatino_df_copy = RA_HispanicORlatino_df_copy.rename(columns={'Total Female, 18-44': 'Total HispanicORlatino Female, 18-44'})
RA_HispanicORlatino_df_copy
# Out:
#                                              Total HispanicORlatino Female, 18-44
# Geographic Area Name
# Census Tract 9502, Appling County, Georgia                                     37
# Census Tract 9503, Appling County, Georgia                                    116
# Census Tract 9504, Appling County, Georgia                                     30
# Census Tract 9505, Appling County, Georgia                                    138
# Census Tract 9601, Atkinson County, Georgia                                    97
# ...                                                                           ...
# Census Tract 9501, Worth County, Georgia                                        0
# Census Tract 9502, Worth County, Georgia                                        0
# Census Tract 9504, Worth County, Georgia                                        0
# Census Tract 9505, Worth County, Georgia                                        0
# ...

# %%
RA_BlackorAfricanAmerican=pd.read_csv('../../Obstetric accessibility visualization/Georgia/BlackorAfricanAmericanRace.csv')
RA_BlackorAfricanAmerican.head()
# Out:
#                  GEO_ID                                        NAME  \
# 0             Geography                        Geographic Area Name
# 1  1400000US13001950100  Census Tract 9501, Appling County, Georgia
# 2  1400000US13001950200  Census Tract 9502, Appling County, Georgia
# 3  1400000US13001950300  Census Tract 9503, Appling County, Georgia
# 4  1400000US13001950400  Census Tract 9504, Appling County, Georgia
#
#       B01001B_001E                  B01001B_001EA            B01001B_001M  \
# 0  Estimate!!Total  Annotation of Estimate!!Total  Margin of Error!!Total
# 1               91                            NaN                      65
# 2             1698                            NaN                     385
# 3              934                            NaN                     382
# 4              395                            NaN                     182
#
#                           B01001B_001MA           B01001B_002E  \
# ...

# %%
RA_BlackorAfricanAmerican.rename(columns=RA_BlackorAfricanAmerican.iloc[0], inplace=True)
RA_BlackorAfricanAmerican_df = RA_BlackorAfricanAmerican[[
    'Geographic Area Name',
    'Estimate!!Total!!Female!!18 and 19 years',
    'Estimate!!Total!!Female!!20 to 24 years',
    'Estimate!!Total!!Female!!25 to 29 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!35 to 44 years',
]]
RA_BlackorAfricanAmerican_df_copy = RA_BlackorAfricanAmerican_df.copy()
RA_BlackorAfricanAmerican_df_copy.drop(RA_BlackorAfricanAmerican_df.index[0], inplace=True)
RA_BlackorAfricanAmerican_df_copy = RA_BlackorAfricanAmerican_df_copy.set_index('Geographic Area Name')
RA_BlackorAfricanAmerican_df_copy = RA_BlackorAfricanAmerican_df_copy.iloc[1:]
RA_BlackorAfricanAmerican_df_copy = RA_BlackorAfricanAmerican_df_copy.astype(int)
RA_BlackorAfricanAmerican_df_copy['Total Female, 18-44'] = RA_BlackorAfricanAmerican_df_copy.sum(axis=1)
RA_BlackorAfricanAmerican_df_copy = RA_BlackorAfricanAmerican_df_copy[['Total Female, 18-44']]
RA_BlackorAfricanAmerican_df_copy = RA_BlackorAfricanAmerican_df_copy.rename(columns={'Total Female, 18-44': 'Total BlackorAfricanAmerican Female, 18-44'})
RA_BlackorAfricanAmerican_df_copy.head(100)
# Out:
#                                              Total BlackorAfricanAmerican Female, 18-44
# Geographic Area Name
# Census Tract 9502, Appling County, Georgia                                          233
# Census Tract 9503, Appling County, Georgia                                          217
# Census Tract 9504, Appling County, Georgia                                           19
# Census Tract 9505, Appling County, Georgia                                           28
# Census Tract 9601, Atkinson County, Georgia                                          50
# ...                                                                                 ...
# Census Tract 132.01, Bibb County, Georgia                                          1313
# Census Tract 132.02, Bibb County, Georgia                                           464
# Census Tract 133.02, Bibb County, Georgia                                           789
# ...

# %%
RA_Asian=pd.read_csv('../../Obstetric accessibility visualization/Georgia/AsianRace.csv')

# %%
RA_Asian.rename(columns=RA_Asian.iloc[0], inplace=True)
RA_Asian_df = RA_Asian[[
    'Geographic Area Name',
    'Estimate!!Total!!Female!!18 and 19 years',
    'Estimate!!Total!!Female!!20 to 24 years',
    'Estimate!!Total!!Female!!25 to 29 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!35 to 44 years',
]]
RA_Asian_df_copy = RA_Asian_df.copy()
RA_Asian_df_copy.drop(RA_Asian_df.index[0], inplace=True)
RA_Asian_df_copy = RA_Asian_df_copy.set_index('Geographic Area Name')
RA_Asian_df_copy = RA_Asian_df_copy.iloc[1:]
RA_Asian_df_copy = RA_Asian_df_copy.astype(int)
RA_Asian_df_copy['Total Female, 18-44'] = RA_Asian_df_copy.sum(axis=1)
RA_Asian_df_copy = RA_Asian_df_copy[['Total Female, 18-44']]
RA_Asian_df_copy = RA_Asian_df_copy.rename(columns={'Total Female, 18-44': 'Total Asian Female, 18-44'})
RA_Asian_df_copy
# Out:
#                                              Total Asian Female, 18-44
# Geographic Area Name
# Census Tract 9502, Appling County, Georgia                           0
# Census Tract 9503, Appling County, Georgia                          29
# Census Tract 9504, Appling County, Georgia                           0
# Census Tract 9505, Appling County, Georgia                           0
# Census Tract 9601, Atkinson County, Georgia                          0
# ...                                                                ...
# Census Tract 9501, Worth County, Georgia                            10
# Census Tract 9502, Worth County, Georgia                             0
# Census Tract 9504, Worth County, Georgia                            12
# Census Tract 9505, Worth County, Georgia                             9
# Census Tract 9506, Worth County, Georgia                             0
#
# [1968 rows x 1 columns]

# %%
RA_AmericanIndianORAlaskaNative=pd.read_csv('../../Obstetric accessibility visualization/Georgia/AmericanIndian&AlaskaNative.csv')

# %%
RA_AmericanIndianORAlaskaNative.rename(columns=RA_AmericanIndianORAlaskaNative.iloc[0], inplace=True)
RA_AmericanIndianORAlaskaNative_df = RA_AmericanIndianORAlaskaNative[[
    'Geographic Area Name',
    'Estimate!!Total!!Female!!18 and 19 years',
    'Estimate!!Total!!Female!!20 to 24 years',
    'Estimate!!Total!!Female!!25 to 29 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!35 to 44 years',
]]
RA_AmericanIndianORAlaskaNative_df_copy = RA_AmericanIndianORAlaskaNative_df.copy()
RA_AmericanIndianORAlaskaNative_df_copy.drop(RA_AmericanIndianORAlaskaNative_df.index[0], inplace=True)
RA_AmericanIndianORAlaskaNative_df_copy = RA_AmericanIndianORAlaskaNative_df_copy.set_index('Geographic Area Name')
RA_AmericanIndianORAlaskaNative_df_copy = RA_AmericanIndianORAlaskaNative_df_copy.iloc[1:]
RA_AmericanIndianORAlaskaNative_df_copy = RA_AmericanIndianORAlaskaNative_df_copy.astype(int)
RA_AmericanIndianORAlaskaNative_df_copy['Total Female, 18-44'] = RA_AmericanIndianORAlaskaNative_df_copy.sum(axis=1)
RA_AmericanIndianORAlaskaNative_df_copy = RA_AmericanIndianORAlaskaNative_df_copy[['Total Female, 18-44']]
RA_AmericanIndianORAlaskaNative_df_copy = RA_AmericanIndianORAlaskaNative_df_copy.rename(columns={'Total Female, 18-44': 'Total AmericanIndianORAlaskaNative Female, 18-44'})
RA_AmericanIndianORAlaskaNative_df_copy
# Out:
#                                              Total AmericanIndianORAlaskaNative Female, 18-44
# Geographic Area Name
# Census Tract 9502, Appling County, Georgia                                                 22
# Census Tract 9503, Appling County, Georgia                                                  0
# Census Tract 9504, Appling County, Georgia                                                  0
# Census Tract 9505, Appling County, Georgia                                                  0
# Census Tract 9601, Atkinson County, Georgia                                                 0
# ...                                                                                       ...
# Census Tract 9501, Worth County, Georgia                                                    0
# Census Tract 9502, Worth County, Georgia                                                    0
# Census Tract 9504, Worth County, Georgia                                                    0
# ...

# %%
RA_NativeHawaiinOtherPacificIslander=pd.read_csv('../../Obstetric accessibility visualization/Georgia/NativeHawaiin&OtherPacificIslander.csv')

# %%
RA_NativeHawaiinOtherPacificIslander.rename(columns=RA_NativeHawaiinOtherPacificIslander.iloc[0], inplace=True)
RA_NativeHawaiinOtherPacificIslander_df = RA_NativeHawaiinOtherPacificIslander[[
    'Geographic Area Name',
    'Estimate!!Total!!Female!!18 and 19 years',
    'Estimate!!Total!!Female!!20 to 24 years',
    'Estimate!!Total!!Female!!25 to 29 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!35 to 44 years',
]]
RA_NativeHawaiinOtherPacificIslander_df_copy = RA_NativeHawaiinOtherPacificIslander_df.copy()
RA_NativeHawaiinOtherPacificIslander_df_copy.drop(RA_NativeHawaiinOtherPacificIslander_df.index[0], inplace=True)
RA_NativeHawaiinOtherPacificIslander_df_copy = RA_NativeHawaiinOtherPacificIslander_df_copy.set_index('Geographic Area Name')
RA_NativeHawaiinOtherPacificIslander_df_copy = RA_NativeHawaiinOtherPacificIslander_df_copy.iloc[1:]
RA_NativeHawaiinOtherPacificIslander_df_copy = RA_NativeHawaiinOtherPacificIslander_df_copy.astype(int)
RA_NativeHawaiinOtherPacificIslander_df_copy['Total Female, 18-44'] = RA_NativeHawaiinOtherPacificIslander_df_copy.sum(axis=1)
RA_NativeHawaiinOtherPacificIslander_df_copy = RA_NativeHawaiinOtherPacificIslander_df_copy[['Total Female, 18-44']]
RA_NativeHawaiinOtherPacificIslander_df_copy = RA_NativeHawaiinOtherPacificIslander_df_copy.rename(columns={'Total Female, 18-44': 'Total NativeHawaiin&OtherPacificIslander Female, 18-44'})
RA_NativeHawaiinOtherPacificIslander_df_copy
# Out:
#                                              Total NativeHawaiin&OtherPacificIslander Female, 18-44
# Geographic Area Name
# Census Tract 9502, Appling County, Georgia                                                   0
# Census Tract 9503, Appling County, Georgia                                                   0
# Census Tract 9504, Appling County, Georgia                                                   0
# Census Tract 9505, Appling County, Georgia                                                   0
# Census Tract 9601, Atkinson County, Georgia                                                  0
# ...                                                                                        ...
# Census Tract 9501, Worth County, Georgia                                                     0
# Census Tract 9502, Worth County, Georgia                                                     0
# Census Tract 9504, Worth County, Georgia                                                     0
# ...

# %%
merged_df = RA_AmericanIndianORAlaskaNative_df_copy.merge(RA_BlackorAfricanAmerican_df_copy, on='Geographic Area Name').merge(RA_HispanicORlatino_df_copy, on='Geographic Area Name').merge(RA_White_df_copy, on='Geographic Area Name').merge(RA_Asian_df_copy, on='Geographic Area Name').merge(RA_NativeHawaiinOtherPacificIslander_df_copy, on='Geographic Area Name')
merged_df
# Out:
#                                              Total AmericanIndianORAlaskaNative Female, 18-44  \
# Geographic Area Name
# Census Tract 9502, Appling County, Georgia                                                 22
# Census Tract 9503, Appling County, Georgia                                                  0
# Census Tract 9504, Appling County, Georgia                                                  0
# Census Tract 9505, Appling County, Georgia                                                  0
# Census Tract 9601, Atkinson County, Georgia                                                 0
# ...                                                                                       ...
# Census Tract 9501, Worth County, Georgia                                                    0
# Census Tract 9502, Worth County, Georgia                                                    0
# Census Tract 9504, Worth County, Georgia                                                    0
# ...

# %%
def calculate_proportions(row):
    row_sum = row.sum()
    if row_sum != 0:
        return row / row_sum
    else:
        return row

# Apply the function to each row
proportion_df = merged_df.apply(calculate_proportions, axis=1)

# Display the resulting DataFrame
proportion_df
#
# Out:
#                                              Total AmericanIndianORAlaskaNative Female, 18-44  \
# Geographic Area Name
# Census Tract 9502, Appling County, Georgia                                           0.033742
# Census Tract 9503, Appling County, Georgia                                           0.000000
# Census Tract 9504, Appling County, Georgia                                           0.000000
# Census Tract 9505, Appling County, Georgia                                           0.000000
# Census Tract 9601, Atkinson County, Georgia                                          0.000000
# ...                                                                                       ...
# Census Tract 9501, Worth County, Georgia                                             0.000000
# Census Tract 9502, Worth County, Georgia                                             0.000000
# Census Tract 9504, Worth County, Georgia                                             0.000000
# ...

# %%
proportion_df=proportion_df.reset_index()


proportion_df
# Out:
#                              Geographic Area Name  \
# 0      Census Tract 9502, Appling County, Georgia
# 1      Census Tract 9503, Appling County, Georgia
# 2      Census Tract 9504, Appling County, Georgia
# 3      Census Tract 9505, Appling County, Georgia
# 4     Census Tract 9601, Atkinson County, Georgia
# ...                                           ...
# 1963     Census Tract 9501, Worth County, Georgia
# 1964     Census Tract 9502, Worth County, Georgia
# 1965     Census Tract 9504, Worth County, Georgia
# 1966     Census Tract 9505, Worth County, Georgia
# 1967     Census Tract 9506, Worth County, Georgia
#
#       Total AmericanIndianORAlaskaNative Female, 18-44  \
# 0                                             0.033742
# 1                                             0.000000
# 2                                             0.000000
# 3                                             0.000000
# 4                                             0.000000
# ...

# %%
import pandas as pd
RA_Georgia_BG=pd.read_csv('../../Obstetric accessibility visualization/Indiana/RA_NativeHawaiin_censusTract.csv')
RA_Georgia_BG.head()
RA_Georgia_BG.rename(columns=RA_Georgia_BG.iloc[0], inplace=True)
RA_Georgia_BG.columns
RA_Georgia_BG_df = RA_Georgia_BG[[
    'Geographic Area Name',
    'Estimate!!Total!!Female!!18 and 19 years',
    'Estimate!!Total!!Female!!20 years',
    'Estimate!!Total!!Female!!22 to 24 years',
    'Estimate!!Total!!Female!!25 to 29 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!35 to 39 years',
    'Estimate!!Total!!Female!!40 to 44 years'
]]

RA_Georgia_BG_df_copy = RA_Georgia_BG_df.copy()
RA_Georgia_BG_df_copy.drop(RA_Georgia_BG_df.index[0], inplace=True)
age_columns = [
    'Estimate!!Total!!Female!!18 and 19 years',
    'Estimate!!Total!!Female!!20 years',
    'Estimate!!Total!!Female!!22 to 24 years',
    'Estimate!!Total!!Female!!25 to 29 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!30 to 34 years',
    'Estimate!!Total!!Female!!35 to 39 years',
    'Estimate!!Total!!Female!!40 to 44 years'
]

RA_Georgia_BG_df_copy
# Out:
#                                    Geographic Area Name  \
# 1     Block Group 1, Census Tract 9501, Appling Coun...
# 2     Block Group 2, Census Tract 9501, Appling Coun...
# 3     Block Group 1, Census Tract 9502, Appling Coun...
# 4     Block Group 2, Census Tract 9502, Appling Coun...
# 5     Block Group 3, Census Tract 9502, Appling Coun...
# ...                                                 ...
# 5529  Block Group 1, Census Tract 9505, Worth County...
# 5530  Block Group 2, Census Tract 9505, Worth County...
# 5531  Block Group 3, Census Tract 9505, Worth County...
# 5532  Block Group 1, Census Tract 9506, Worth County...
# 5533  Block Group 2, Census Tract 9506, Worth County...
#
#      Estimate!!Total!!Female!!18 and 19 years  \
# 1                                           0
# 2                                          39
# 3                                          28
# 4                                          23
# 5                                          22
# ...

# %% [markdown]
# <h2> RA_Count_BG_level </h2>

# %%
for col in age_columns:
    if col in RA_Georgia_BG_df_copy.columns:
        RA_Georgia_BG_df_copy[col] = RA_Georgia_BG_df_copy[col].astype(str)  # Ensure it's a string
        RA_Georgia_BG_df_copy[col] = RA_Georgia_BG_df_copy[col].apply(lambda x: pd.to_numeric(x, errors='coerce'))

# Create the new column by summing the specified columns
RA_Georgia_BG_df_copy['Total Female Age 18-44 years'] = RA_Georgia_BG_df_copy[age_columns].sum(axis=1)

# Drop all other columns except 'Geographic Area Name' and the new column
RA_Georgia_BG_df_copy = RA_Georgia_BG_df_copy[['Geographic Area Name', 'Total Female Age 18-44 years']]
RA_Georgia_BG_df_copy.rename(columns={'Geographic Area Name': 'Geographic Area Names'}, inplace=True)
# Display the resulting DataFrame
RA_Georgia_BG_df_copy

RA_Georgia_BG_df_copy['Geographic Area Name'] = RA_Georgia_BG_df_copy['Geographic Area Names'].str.extract(r'Block Group \d+, (.*)')

RA_Georgia_BG_df_copy.head()
# Out:
# /var/folders/_2/chm4htkx0yj_5655k61rx6tc0000gn/T/ipykernel_76635/1838968070.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RA_Georgia_BG_df_copy.rename(columns={'Geographic Area Name': 'Geographic Area Names'}, inplace=True)
# /var/folders/_2/chm4htkx0yj_5655k61rx6tc0000gn/T/ipykernel_76635/1838968070.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   RA_Georgia_BG_df_copy['Geographic Area Name'] = RA_Georgia_BG_df_copy['Geographic Area Names'].str.extract(r'Block Group \d+, (.*)')
#                                Geographic Area Names  \
# ...

# %%
merged_df = pd.merge(RA_Georgia_BG_df_copy, proportion_df, on='Geographic Area Name')
merged_df.head()
# Out:
#                                Geographic Area Names  \
# 0  Block Group 1, Census Tract 9502, Appling Coun...
# 1  Block Group 2, Census Tract 9502, Appling Coun...
# 2  Block Group 3, Census Tract 9502, Appling Coun...
# 3  Block Group 1, Census Tract 9503, Appling Coun...
# 4  Block Group 2, Census Tract 9503, Appling Coun...
#
#    Total Female Age 18-44 years                        Geographic Area Name  \
# 0                           468  Census Tract 9502, Appling County, Georgia
# 1                           234  Census Tract 9502, Appling County, Georgia
# 2                           195  Census Tract 9502, Appling County, Georgia
# 3                           328  Census Tract 9503, Appling County, Georgia
# 4                           537  Census Tract 9503, Appling County, Georgia
#
#    Total AmericanIndianORAlaskaNative Female, 18-44  \
# 0                                          0.033742
# 1                                          0.033742
# ...

# %%
columns_to_multiply = [
    'Total AmericanIndianORAlaskaNative Female, 18-44',
       'Total BlackorAfricanAmerican Female, 18-44',
       'Total HispanicORlatino Female, 18-44', 'Total White Female, 18-44',
       'Total Asian Female, 18-44',
       'Total NativeHawaiin&OtherPacificIslander Female, 18-44'
]

# Performing the multiplication
for column in columns_to_multiply:
    merged_df[column] = (merged_df[column] * merged_df['Total Female Age 18-44 years'])

# Display the modified DataFrame
merged_df
# Out:
#                                   Geographic Area Names  \
# 0     Block Group 1, Census Tract 9502, Appling Coun...
# 1     Block Group 2, Census Tract 9502, Appling Coun...
# 2     Block Group 3, Census Tract 9502, Appling Coun...
# 3     Block Group 1, Census Tract 9503, Appling Coun...
# 4     Block Group 2, Census Tract 9503, Appling Coun...
# ...                                                 ...
# 5526  Block Group 1, Census Tract 9505, Worth County...
# 5527  Block Group 2, Census Tract 9505, Worth County...
# 5528  Block Group 3, Census Tract 9505, Worth County...
# 5529  Block Group 1, Census Tract 9506, Worth County...
# 5530  Block Group 2, Census Tract 9506, Worth County...
#
#       Total Female Age 18-44 years  \
# 0                              468
# 1                              234
# 2                              195
# 3                              328
# 4                              537
# ...                            ...
# 5526                           376
# ...

# %%
columns_to_round = [
    'Total AmericanIndianORAlaskaNative Female, 18-44',
       'Total BlackorAfricanAmerican Female, 18-44',
       'Total HispanicORlatino Female, 18-44', 'Total White Female, 18-44',
       'Total Asian Female, 18-44',
       'Total NativeHawaiin&OtherPacificIslander Female, 18-44'
]

for index, row in merged_df.iterrows():
    # Round all but the last value
    for column in columns_to_round[:-1]:
        merged_df.at[index, column] = round(row[column])
    
    # Calculate the last value to ensure the sum matches the Population
    last_column = columns_to_round[-1]
    merged_df.at[index, last_column] = row['Total Female Age 18-44 years'] - sum([round(row[col]) for col in columns_to_round[:-1]])
    
merged_df.drop('Geographic Area Name', axis=1, inplace=True)

# %%
merged_df.head()
# Out:
#                                Geographic Area Names  \
# 0  Block Group 1, Census Tract 9502, Appling Coun...
# 1  Block Group 2, Census Tract 9502, Appling Coun...
# 2  Block Group 3, Census Tract 9502, Appling Coun...
# 3  Block Group 1, Census Tract 9503, Appling Coun...
# 4  Block Group 2, Census Tract 9503, Appling Coun...
#
#    Total Female Age 18-44 years  \
# 0                           468
# 1                           234
# 2                           195
# 3                           328
# 4                           537
#
#    Total AmericanIndianORAlaskaNative Female, 18-44  \
# 0                                              16.0
# 1                                               8.0
# 2                                               7.0
# 3                                               0.0
# 4                                               0.0
#
#    Total BlackorAfricanAmerican Female, 18-44  \
# 0                                       167.0
# ...

# %%
import os
os.chdir()
# Out:
# '/Users/ayushigoyal/Obstetric accessibility visualization/Georgia'

# %%
merged_df.to_csv('Distribution_across_Race.csv', index=False)
